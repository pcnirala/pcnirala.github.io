# %% [markdown]
# # QF627 Pre-Course Workshop | Introduction to Programming
# ## Lesson 04 | An Introduction to `pandas` Part 2 | `RE`view

# %% [markdown]
# > Yes, first a little setup. Importing the `pandas` library as `pd`

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
import pandas as pd

# %% [markdown]
# ### Let's set some helpful display options.
#
# > Uncomment the boilerplate in this cell.

# %% [markdown]
# ## IMPORT

# %% [markdown]
# ### Let's open and read in the `players.csv` and `salaries.csv` tables in the `qf627` directory

# %%
import os

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# os         module    <module 'os' from '/Users<...>env/lib/python3.9/os.py'>
# pd         module    <module 'pandas' from '/U<...>ages/pandas/__init__.py'>

# %%
os.listdir()[0]
# Out:
# 'salaries.csv'

# %%
os\
    .listdir()
# Out:
# ['salaries.csv',
#  'Exercise_Data_January.csv',
#  'QF627_PreCourse_01_Introduction_REview.ipynb',
#  '.DS_Store',
#  'Exercise_Data_February.csv',
#  'countries.csv',
#  'Exercise_Data_April.csv',
#  'Exercise_Data_March.csv',
#  'Exercise_Data_August.csv',
#  'QF627_PreCourse_Problem_Sets.ipynb',
#  'Exercise_Data_December.csv',
#  'Exercise_Data_November.csv',
#  'QF627_PreCourse_03_matplotlib_InProgress_2.ipynb',
#  'matplotlib.png',
#  'QF627_PreCourse_02_NumPy_REview.ipynb',
#  'players.csv',
#  'Exercise_Data_October.csv',
#  'plot_with_shapes.png',
#  'Exercise_Data_June.csv',
#  '2016_census_data.csv',
#  'Exercise_Data_July.csv',
#  '.ipynb_checkpoints',
#  'Exercise_Data_May.csv',
#  'QF627_PreCourse_04_pandas_Part2_Preview.ipynb',
#  'Exercise_Data_September.csv',
#  'ndim.png',
#  'QF627_PreCourse_04_pandas_Part1_Preview.ipynb']

# %%
players =\
(
    pd
    .read_csv("players.csv")
)

salaries =\
(
    pd
    .read_csv("salaries.csv")
)

# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# os         module       <module 'os' from '/Users<...>env/lib/python3.9/os.py'>
# pd         module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# players    DataFrame            playerID  birthYe<...>[18846 rows x 24 columns]
# salaries   DataFrame           yearID teamID lgID<...>n[25575 rows x 5 columns]

# %% [markdown]
# > Let's check to see what type each object is with `print(table_name)`.
#
# > You can also use the `.info()` method to explore the data's structure.

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18846 entries, 0 to 18845
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   playerID      18846 non-null  object
#  1   birthYear     18703 non-null  float64
#  2   birthMonth    18531 non-null  float64
#  3   birthDay      18382 non-null  float64
#  4   birthCountry  18773 non-null  object
#  5   birthState    18220 non-null  object
#  6   birthCity     18647 non-null  object
#  7   deathYear     9336 non-null   float64
#  8   deathMonth    9335 non-null   float64
#  9   deathDay      9334 non-null   float64
#  10  deathCountry  9329 non-null   object
#  11  deathState    9277 non-null   object
#  12  deathCity     9325 non-null   object
#  13  nameFirst     18807 non-null  object
#  14  nameLast      18846 non-null  object
#  15  nameGiven     18807 non-null  object
#  16  weight        17975 non-null  float64
#  17  height        18041 non-null  float64
#  18  bats          17655 non-null  object
#  19  throws        17868 non-null  object
#  20  debut         18653 non-null  object
#  21  finalGame     18653 non-null  object
#  22  retroID       18792 non-null  object
#  23  bbrefID       18845 non-null  object
# dtypes: float64(8), object(16)
# memory usage: 3.5+ MB

# %%
~1
# Out:
# -2

# %%
~True
# Out:
# -2

# %%
(
    players
    .isnull() # returns Bool
    .mean() # .mean() returns the prop. of cases of being 1
).to_frame()
# Out:
#                      0
# playerID      0.000000
# birthYear     0.007588
# birthMonth    0.016714
# birthDay      0.024621
# birthCountry  0.003874
# birthState    0.033217
# birthCity     0.010559
# deathYear     0.504616
# deathMonth    0.504669
# deathDay      0.504722
# deathCountry  0.504988
# deathState    0.507747
# deathCity     0.505200
# nameFirst     0.002069
# nameLast      0.000000
# nameGiven     0.002069
# weight        0.046217
# height        0.042715
# bats          0.063196
# throws        0.051894
# debut         0.010241
# finalGame     0.010241
# retroID       0.002865
# bbrefID       0.000053

# %%
(
    players
    .isnull() # returns Bool
    .sum() # .sum() returns the number of cases of being 1
)
# Out:
# playerID           0
# birthYear        143
# birthMonth       315
# birthDay         464
# birthCountry      73
# birthState       626
# birthCity        199
# deathYear       9510
# deathMonth      9511
# deathDay        9512
# deathCountry    9517
# deathState      9569
# deathCity       9521
# nameFirst         39
# nameLast           0
# nameGiven         39
# weight           871
# height           805
# bats            1191
# throws           978
# debut            193
# finalGame        193
# retroID           54
# bbrefID            1
# dtype: int64

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25575 entries, 0 to 25574
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   yearID    25575 non-null  int64
#  1   teamID    25575 non-null  object
#  2   lgID      25575 non-null  object
#  3   playerID  25575 non-null  object
#  4   salary    25575 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 999.1+ KB

# %%
players.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %%
salaries.columns
# Out:
# Index(['yearID', 'teamID', 'lgID', 'playerID', 'salary'], dtype='object')

# %% [markdown]
# > Let's print out sample data for each table with `table.head()`
#
# > Let's see additional options by pressing `tab` after you type the `head()` method

# %% [markdown]
# ### `.merge()` in pandas

# %%
df_a =\
    pd\
    .DataFrame(
        {"classmates": ["Zealin", "Shi Ling", "Jonathan"],
         "id": [100, 101, 102]}
    )

df_b =\
    pd\
    .DataFrame(                # pay attention here (Shi ling)
        {"classmates": ["Zealin", "Shi ling", "Jonathan"],
         "scores": [100, 101, 102]
        }
    )

# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df_a       DataFrame      classmates   id\n0     <...>g  101\n2   Jonathan  102
# df_b       DataFrame      classmates  scores\n0  <...>101\n2   Jonathan     102
# os         module       <module 'os' from '/Users<...>env/lib/python3.9/os.py'>
# pd         module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# players    DataFrame            playerID  birthYe<...>[18846 rows x 24 columns]
# salaries   DataFrame           yearID teamID lgID<...>n[25575 rows x 5 columns]

# %%
df_a
# Out:
#   classmates   id
# 0     Zealin  100
# 1   Shi Ling  101
# 2   Jonathan  102

# %%
df_b
# Out:
#   classmates  scores
# 0     Zealin     100
# 1   Shi ling     101
# 2   Jonathan     102

# %%
df_a\
    .merge(df_b,
           how = "left",
           on = "classmates")
# Out:
#   classmates   id  scores
# 0     Zealin  100   100.0
# 1   Shi Ling  101     NaN
# 2   Jonathan  102   102.0

# %%
df_a\
    .merge(df_b,
           how = "right",
           on = "classmates")
# Out:
#   classmates     id  scores
# 0     Zealin  100.0     100
# 1   Shi ling    NaN     101
# 2   Jonathan  102.0     102

# %% [markdown]
# > Now let's join the two csv's using `pd.merge`.
#
# > You might want to keep all the players names in the `players` dataset even if their salary is missing from the `salary` data set.
#
# > We can always filter the NaN values out later.

# %%
players.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %% [markdown]
# ```Python
# (
#     players
#     .merge(salaries,
#            how = "left",
#            on = "playerID")
# )

# %%
merged_DF =\
(
    pd
    .merge(how = "left",
           left = players,
           right = salaries)
)

# %%
merged_DF.shape
# Out:
# (39455, 28)

# %%
print(players.shape);print(salaries.shape)
# Out:
# (18846, 24)
# (25575, 5)

# %%
merged_DF.shape[1] == players.shape[1] + salaries.shape[1] - 1
# Out:
# True

# %% [markdown]
# > Let's see what columns the `joined` table contains

# %%
merged_DF.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID', 'yearID', 'teamID', 'lgID', 'salary'],
#       dtype='object')

# %% [markdown]
# > Please check if all the players have a salary assigned.
#
# > The easiest way is to deduct the length of the `joined` table from the `players` table

# %%
len(players) - len(merged_DF)
# Out:
# -20609

# %% [markdown]
# > Bummer, something went wrong.
#
# > There are now more players in the `joined` dataset than in the `players` dataset.
#
# > `Some entries probably got duplicated.`
#
# > Let's check if we have duplicate `playerIDs` by using `.value_counts()`

# %%
(
    merged_DF
    .playerID
    .value_counts()
)
# Out:
# playerID
# moyerja01    25
# vizquom01    24
# glavito02    23
# bondsba01    22
# griffke02    22
#              ..
# hardtja01     1
# hardyal01     1
# hardybl01     1
# hardyca01     1
# zychto01      1
# Name: count, Length: 18846, dtype: int64

# %%
merged_DF.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID', 'yearID', 'teamID', 'lgID', 'salary'],
#       dtype='object')

# %% [markdown]
# ##### Yep, we do.
#
# > Let's filter out an arbitrary player to see why there is duplication.

# %%
for_cleaning =\
(
    merged_DF
    .sort_values(["playerID", "yearID"]
                )
)

# %% [markdown]
# > As we can see, there are now salaries in the dataset for each year of the players carreer.
#
# > Here, you only want to have the most recent salary though.
#
# > To resolve this, let's **`de`duplicate** the dataset.

# %%
for_cleaning[["playerID", "yearID"]]
# Out:
#         playerID  yearID
# 0      aardsda01  2004.0
# 1      aardsda01  2007.0
# 2      aardsda01  2008.0
# 3      aardsda01  2009.0
# 4      aardsda01  2010.0
# ...          ...     ...
# 39450   zupofr01     NaN
# 39451  zuvelpa01  1989.0
# 39452  zuverge01     NaN
# 39453  zwilldu01     NaN
# 39454   zychto01     NaN
#
# [39455 rows x 2 columns]

# %% [markdown]
# ##### But first, let's make sure we get the newest year.
#
# > We can do this by sorting the data on the newest entry

# %%
data_with_most_recent_year =\
(
    for_cleaning # team, this DF is in ascending order
    .drop_duplicates("playerID",
                     keep = "last")
)

# %% [markdown]
# > Now we **`de`duplicate**.

# %%
data_with_most_recent_year.shape[0] == players.shape[0]
# Out:
# True

# %% [markdown]
# > And let's do the check again!

# %%
len(players) == len(data_with_most_recent_year)
# Out:
# True

# %% [markdown]
# > Yay! Now let's get into the interesting part: analysis :)

# %% [markdown]
# ## What is the average (mean, median, max, min) salary?

# %%
data_with_most_recent_year\
    .salary\
    .describe()\
    .to_frame()\
    .T
# Out:
#          count          mean           std  min       25%       50%
# salary  4958.0  1.692478e+06  3.243005e+06  0.0  300000.0  507500.0  \
#
#               75%         max
# salary  1300000.0  32571000.0

# %% [markdown]
# ## Who makes the most money?

# %%
max_salary =\
(
    data_with_most_recent_year
    .salary
    .max()
)

max_salary
# Out:
# 32571000.0

# %%
player_with_max_salary =\
    data_with_most_recent_year[data_with_most_recent_year["salary"] == max_salary]

player_with_max_salary
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState
# 18735  kershcl01     1988.0         3.0      19.0          USA         TX  \
#
#       birthCity  deathYear  deathMonth  deathDay  ... bats throws       debut
# 18735    Dallas        NaN         NaN       NaN  ...    L      L  2008-05-25  \
#
#         finalGame   retroID    bbrefID  yearID  teamID lgID      salary
# 18735  2015-10-04  kersc001  kershcl01  2015.0     LAN   NL  32571000.0
#
# [1 rows x 28 columns]

# %% [markdown]
# ## What are the most common baseball players salaries?

# %% [markdown]
# > Let's draw a histogram.

# %%
data_with_most_recent_year.hist("salary", 
                                bins = 100)
# Out:
# array([[<Axes: title={'center': 'salary'}>]], dtype=object)

# %% [markdown]
# > You can do the same with the column `yearID` to see how recent our data is.
#
# > We have 30 years in our dataset, so we need to do some minor tweaking--namely, resetting the bins.

# %%
data_with_most_recent_year.hist("yearID")
# Out:
# array([[<Axes: title={'center': 'yearID'}>]], dtype=object)

# %% [markdown]
# ## Who are the top 10% highest-paid players?

# %% [markdown]
# > Let's calculate the 90 percentile cutoff.

# %%
cutoff_90 =\
(
    data_with_most_recent_year
    .salary
    .quantile(q = .90)
)

# %%
cutoff_90
# Out:
# 4500000.0

# %% [markdown]
# > Let's filter out players that make more money than the cutoff.

# %%
data_with_most_recent_year.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID', 'yearID', 'teamID', 'lgID', 'salary'],
#       dtype='object')

# %%
top10_percentile_players =\
    data_with_most_recent_year[data_with_most_recent_year["salary"] >= cutoff_90]

top10_percentile_players[['nameFirst', 'nameLast']]
# Out:
#       nameFirst    nameLast
# 91        Bobby       Abreu
# 94         Jose       Abreu
# 181        Mike       Adams
# 237      Jeremy     Affeldt
# 395     Edgardo     Alfonzo
# ...         ...         ...
# 39364      Brad     Ziegler
# 39387    Jordan  Zimmermann
# 39397      Ryan   Zimmerman
# 39421     Barry        Zito
# 39432       Ben     Zobrist
#
# [505 rows x 2 columns]

# %% [markdown]
# > Let's use the `nlargest` to see the top 10 best paid players.

# %%
top10_players =\
    top10_percentile_players\
    .nlargest(10,
              "salary")

top10_players[['nameFirst', 'nameLast']]
# Out:
#       nameFirst   nameLast
# 18735   Clayton    Kershaw
# 36569    Justin  Verlander
# 13538      Zack    Greinke
# 16479      Ryan     Howard
# 20087     Cliff        Lee
# 15555     Felix  Hernandez
# 37613    Vernon      Wells
# 5384   Robinson       Cano
# 10823    Prince    Fielder
# 28702    Albert     Pujols

# %% [markdown]
# > Now let's visualize the results.

# %%
top10_players.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID', 'yearID', 'teamID', 'lgID', 'salary'],
#       dtype='object')

# %%
top10_players\
    .plot(kind = "barh", # bar`h` horizontal
          x = "nameGiven",
          y = "salary"
          )
# Out:
# <Axes: ylabel='nameGiven'>

# %% [markdown]
# > Let's save the data.

# %%
top10_players\
    .to_csv("top10_players.csv",
            index = False)

# %%
# %ls
# Out:
# 2016_census_data.csv
# Exercise_Data_April.csv
# Exercise_Data_August.csv
# Exercise_Data_December.csv
# Exercise_Data_February.csv
# Exercise_Data_January.csv
# Exercise_Data_July.csv
# Exercise_Data_June.csv
# Exercise_Data_March.csv
# Exercise_Data_May.csv
# Exercise_Data_November.csv
# Exercise_Data_October.csv
# Exercise_Data_September.csv
# QF627_PreCourse_01_Introduction_REview.ipynb
# QF627_PreCourse_02_NumPy_REview.ipynb
# QF627_PreCourse_03_matplotlib_REview.ipynb
# QF627_PreCourse_04_pandas_Part1_REview.ipynb
# QF627_PreCourse_04_pandas_Part2_InProgress.ipynb
# QF627_PreCourse_Problem_Sets.ipynb
# countries.csv
# matplotlib.png
# ndim.png
# players.csv
# plot_with_shapes.png
# salaries.csv
# top10_players.csv

# %%
imported_data =\
(
    pd
    .read_csv("top10_players.csv")
)

# %%
imported_data
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry
# 0  kershcl01     1988.0         3.0      19.0          USA  \
# 1  verlaju01     1983.0         2.0      20.0          USA
# 2  greinza01     1983.0        10.0      21.0          USA
# 3  howarry01     1979.0        11.0      19.0          USA
# 4    leecl02     1978.0         8.0      30.0          USA
# 5  hernafe02     1986.0         4.0       8.0    Venezuela
# 6  wellsve01     1978.0        12.0       8.0          USA
# 7   canoro01     1982.0        10.0      22.0         D.R.
# 8  fieldpr01     1984.0         5.0       9.0          USA
# 9  pujolal01     1980.0         1.0      16.0         D.R.
#
#              birthState             birthCity  deathYear  deathMonth
# 0                    TX                Dallas        NaN         NaN  \
# 1                    VA         Manakin Sabot        NaN         NaN
# 2                    FL               Orlando        NaN         NaN
# 3                    MO             St. Louis        NaN         NaN
# 4                    AR                Benton        NaN         NaN
# 5              Carabobo              Valencia        NaN         NaN
# 6                    LA            Shreveport        NaN         NaN
# 7  San Pedro de Macoris  San Pedro de Macoris        NaN         NaN
# 8                    CA               Ontario        NaN         NaN
# 9     Distrito Nacional         Santo Domingo        NaN         NaN
#
#    deathDay  ...  bats  throws       debut   finalGame   retroID    bbrefID
# 0       NaN  ...     L       L  2008-05-25  2015-10-04  kersc001  kershcl01  \
# 1       NaN  ...     R       R  2005-07-04  2015-10-03  verlj001  verlaju01
# 2       NaN  ...     R       R  2004-05-22  2015-10-03  greiz001  greinza01
# 3       NaN  ...     L       L  2004-09-01  2015-09-14  howar001  howarry01
# 4       NaN  ...     L       L  2002-09-15  2014-07-31  lee-c003    leecl02
# 5       NaN  ...     R       R  2005-08-04  2015-09-26  hernf002  hernafe02
# 6       NaN  ...     R       R  1999-08-30  2013-09-29  wellv001  wellsve01
# 7       NaN  ...     L       R  2005-05-03  2015-10-04  canor001   canoro01
# 8       NaN  ...     L       R  2005-06-13  2015-10-04  fielp001  fieldpr01
# 9       NaN  ...     R       R  2001-04-02  2015-10-04  pujoa001  pujolal01
#
#    yearID  teamID lgID      salary
# 0  2015.0     LAN   NL  32571000.0
# 1  2015.0     DET   AL  28000000.0
# 2  2015.0     LAN   NL  25000000.0
# 3  2015.0     PHI   NL  25000000.0
# 4  2014.0     PHI   NL  25000000.0
# 5  2015.0     SEA   AL  24857000.0
# 6  2013.0     NYA   AL  24642857.0
# 7  2015.0     SEA   AL  24000000.0
# 8  2015.0     TEX   AL  24000000.0
# 9  2015.0     LAA   AL  24000000.0
#
# [10 rows x 28 columns]

# %% [markdown]
# `Thank you for working with the script.`
