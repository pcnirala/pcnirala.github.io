# %% [markdown]
# # QF627 Pre-Course Workshop | Introduction to Programming
#
# ## Lesson 01 | An Informative `Introduction` to Python and Jupyter Notebook | `RE`view

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %% [markdown]
# > Thank you for opening up this script file.
#
# > It would be best if you consider the codes you type here as a new language to communicate with your machine. As long as you provide a complete message in this language, your machine will deliver a reply.

# %% [markdown]
# ### *Why would you use Python?*
#
# * Automate and document routine work (Efficiency)
# * Analyze data in a replicable, documented way (Reproducibility of Your Analysis of Data)
# * Integrates with other language
# * Open source
# * It's easy to learn and use!
#
# Open Terminal on a Mac or CMDR or other bash shell on Windows.
#
# - Type: python3 (you'll get a python command line, >>>)
#
# - Type: 2+3
#
# - Type: import this
#
# - Type: CTRL+d
#
# OK, you could do stuff in there all day.
#
# Or you could put code in a text file with the .py extension and run it from the command line (python_filename.py).
#
# But we're going to use **Jupyter Notebook.**

# %% [markdown]
# ### *Why use Jupyter Notebook?*
#
# * Test your code line by line
# * Rewrite it immediately when you err (and you will err)
# * You can document/explain more extensively using markdown (what you're reading here)
# * Reuse, reuse, reuse

# %% [markdown]
# #### Useful Hotkeys
#
# - `a`: create a cell `a`bove the current cell
# - `m`: convert the current cell into `m`arkdown cell

# %% [markdown]
# - `b`: create a cell `b`elow the current cell
# - `dd`: `d`elete the cell

# %% [markdown]
# - `y`: convert the current cell into code cell

# %% [markdown]
# ### Assignment

# %%
object = 627
# In python, "refers to"
# In C++, "contains"
# In R, "gets" (<-)

# %%
object
# Out:
# 627

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# object     int     627

# %%
# %ls
# Out:
# QF627_PreCourse_01_Introduction_REview.ipynb
# QF627_PreCourse_02_NumPy_Preview.ipynb
# ndim.png

# %% [markdown]
# ### Commands (Functions)

# %%
print(object)
# Out:
# 627

# %%
# print(subject)

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# object     int     627

# %%
print("subject")
# Out:
# subject

# %% [markdown]
# ### Note that to err is expected.
#
# > Bummer! That didn't work.
#
# > But this is the first of many errors you (and especially) will make in Python. In part, because we are typing (check the number of times i type pring instead of print). Also, because it's complicated.
#
# #### ***So a few quick error tips:***
#
# 1. Proofread your code like a copy editor. Errors often result from misspellings, misplaced punctuation, etc.
# 2. Google the error message + Python
# 3. Use [stackoverflow.com](https://stackoverflow.com/) to search the error message or ask questions.
# 4. So let's try using some quotes and parentheses around that word instead.

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# object     int     627

# %%
# our_sample_object = "11"  string
# another_sample_object = 11  integer

# %%
our_sample_object = "11" # string
another_sample_object = 11 # integer

# %%
# %whos
# Out:
# Variable                Type    Data/Info
# -----------------------------------------
# another_sample_object   int     11
# object                  int     627
# our_sample_object       str     11

# %%
11 == "11"
# logical test
# Out:
# False

# %%
float_example = 11.0

# %%
type(float_example) # type() returns data type
# Out:
# float

# %%
another_sample_object == our_sample_object
# Out:
# False

# %% [markdown]
# ### Comments (Annotations to Your Commands)
#
# Basically, anything that is written without a hashtag in the beginning is a command (code).
#
# Anything with a hashtag is a comment. Anything that is followed by a hashtag is not recognized in Python.
#
# The comment is for communication between me and you. The code is for communication between you and your machine.

# %%
1 + 1 # + denotes addition
# Out:
# 2

# %% [markdown]
# > Since we are trying to interact with our machine, one important thing is to think and write your commands in line with the way your machine understand.
#
# > Your machine won't know what you wish to execute, without knowing `data types`.

# %%
type(1)
# Out:
# int

# %%
type("1")
# Out:
# str

# %%
"1" + "1" # + denotes concatenation
# Out:
# '11'

# %% [markdown]
# ### Data Types
#
# Data types are important in Python.
#
# - **Strings** generally text or things you won't do math on (like zip codes)--get quote marks around them.
#
# - **Numerals** don't get quotes, and come in two types: namely, `floats` (floating-point, decimal) and `integers`.
#
# - Then there's **Boolean,** a `True`/`False` type.
#
# But rarely will we simply type in some numbers to add, subtract, multiply and/or divide.
#
# Calculators work for that.
#
# Programming in Python (or any language, really) works by creating building blocks to achieve our goals.
#
# ### Variables
#
# The first of these blocks is a variable.
#
# And it's pretty straightforward: variable_name = "some type of info".

# %%
# 627qf = "qf627"

# %% [markdown]
# ### Variable Names
#
# - Names can be upper or lower case letters, digits, and underscores.
# - Variables `CANNOT` ***start with a digit.***
# - Some variable names are reserved in Python (e.g., class or type) and should beavoided (We will get back to this).

# %% [markdown]
# > Least Squares

# %% [markdown]
# $$
#     \hat{\beta} = (X^TX)^{-1}X^TY
# $$

# %% [markdown]
# Note that it doesn't really matter whether you use single or double quotes.
#
# If you have questions about this or other Python style, consult [here](https://www.python.org/dev/peps/pep-0008/)
#
# It's the Style Guide for Python.
#
# Here's how you would create variables for integers, floats and Booleans.

# %%
float = 627.0

# %%
type(float)
# Out:
# float

# %%
type(2 * 2 == 2 + 2)
# Out:
# bool

# %%
2 * 2 == 2 + 2
# Out:
# True

# %%
sample = 55
type(sample)
# Out:
# int

# %% [markdown]
# Let's learn some `useful hotkeys` for working efficiently on Jupyter Notebook.

# %% [markdown]
# > `shift` + `l`: add `l`ine number

# %%
string_sample = "We are now learning Python :)"

# %% [markdown]
# > shift + control + `-`: `split` the given cell

# %%
string_example = "We are using Python for extracting, analyzing, and deploying our financial models!"

# %%
# %whos
# Out:
# Variable                Type     Data/Info
# ------------------------------------------
# another_sample_object   int      11
# float                   float    627.0
# float_example           float    11.0
# object                  int      627
# our_sample_object       str      11
# sample                  int      55
# string_example          str      We are using Python for e<...>ing our financial models!
# string_sample           str      We are now learning Python :)

# %%
# %who
# Out:
# another_sample_object	 float	 float_example	 object	 our_sample_object	 sample	 string_example	 string_sample

# %% [markdown]
# ### One more thing to note about string

# %%
# sample_string_to_test = 'We'll continue to learn Python tomorrow.'

# %%
sample_string_to_test = "We'll continue to learn Python tomorrow."

# %%
sample_string_to_test = 'We\'ll continue to learn Python tomorrow.' # backward slash (\)

# %%
sample_string_to_test + " " + sample_string_to_test
# Out:
# "We'll continue to learn Python tomorrow. We'll continue to learn Python tomorrow."

# %% [markdown]
# > Let's assess stock trends with fictious variables.

# %%
price = 250
earnigns = 40

PE_ratio = price / earnigns
PE_ratio
# Out:
# 6.25

# %% [markdown]
# > What data type is a variable?
# > Let's get the type of an object.
# > To identify the type, we can use the function `type()`

# %%
type(PE_ratio)
# Out:
# float

# %% [markdown]
# > What if you wish to change variable types?
#
# > What if you want to print "Price to earning ratio is 50.0"?
#
# > Note that you `cannot directly combine floats with strings`.
#
# > If you wish to print combination of floats and strings, you should `convert the floats to strings` first.

# %%
# print("Price to earnings ratio of the company is " + PE_ratio)

# %%
string_PE_ratio = str(PE_ratio)

# %%
type(string_PE_ratio)
# Out:
# str

# %%
print("Price to earnings ratio of the company is " + string_PE_ratio + ".")
# Out:
# Price to earnings ratio of the company is 6.25.

# %%
print("Price to earnings ratio of the company is " + str(PE_ratio) + ".")
# Out:
# Price to earnings ratio of the company is 6.25.

# %% [markdown]
# > How would you be able to switch the following two variables?

# %%
v1 = "first string" # can we store this into v2?
v2 = "second string" # can we store this into v1?

# %%
# %whos
# Out:
# Variable                Type     Data/Info
# ------------------------------------------
# PE_ratio                float    6.25
# another_sample_object   int      11
# earnigns                int      40
# float                   float    627.0
# float_example           float    11.0
# object                  int      627
# our_sample_object       str      11
# price                   int      250
# sample                  int      55
# sample_string_to_test   str      We'll continue to learn Python tomorrow.
# string_PE_ratio         str      6.25
# string_example          str      We are using Python for e<...>ing our financial models!
# string_sample           str      We are now learning Python :)
# v1                      str      first string
# v2                      str      second string

# %%
PE_ratio = 62.5

# %%
# %whos
# Out:
# Variable                Type     Data/Info
# ------------------------------------------
# PE_ratio                float    62.5
# another_sample_object   int      11
# earnigns                int      40
# float                   float    627.0
# float_example           float    11.0
# object                  int      627
# our_sample_object       str      11
# price                   int      250
# sample                  int      55
# sample_string_to_test   str      We'll continue to learn Python tomorrow.
# string_PE_ratio         str      6.25
# string_example          str      We are using Python for e<...>ing our financial models!
# string_sample           str      We are now learning Python :)
# v1                      str      first string
# v2                      str      second string

# %%
PE_ratio
# Out:
# 62.5

# %%
interim_object = v1

v1 = v2 # v1 == "second string"

v2 = interim_object # 

print(v1);print(v2)
# Out:
# second string
# first string

# %% [markdown]
# ### Strings

# %% [markdown]
# >Let's create a string and assign it to a variable.

# %%
string = "We're going to learng Python in QF 627!"

# %%
type(string)
# Out:
# str

# %%
len("Python") == 6
# Out:
# True

# %%
"Python"[0]
# Out:
# 'P'

# %%
"Python"[6-1]
# Out:
# 'n'

# %% [markdown]
# > `Here's what you will be able to do :)`

# %%
import antigravity

# %% [markdown]
# > Make a comment to yourself and then get the length of your string.

# %%
# This is a comment in my code.
string
# Out:
# "We're going to learng Python in QF 627!"

# %% [markdown]
# >Recall that a string is just a series of characters, not a word or a sentence.
#
# >So you can "slice" off pieces of a string based on the index of the characters in it.
#
# >Try to slice off the last 5 characters in `my_string`

# %%
sample_string = "python"

# %%
sample_string
# Out:
# 'python'

# %%
sample_string[1:5]
# Out:
# 'ytho'

# %%
sample_string[-1] == "n"
# Out:
# True

# %%
sample_string[1:-1] == sample_string[1:5]
# Out:
# True

# %%
caps = "PYTHON"

# %%
# %whos
# Out:
# Variable                Type      Data/Info
# -------------------------------------------
# PE_ratio                float     62.5
# another_sample_object   int       11
# antigravity             module    <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# caps                    str       PYTHON
# earnigns                int       40
# float                   float     627.0
# float_example           float     11.0
# interim_object          str       first string
# object                  int       627
# our_sample_object       str       11
# price                   int       250
# sample                  int       55
# sample_string           str       python
# sample_string_to_test   str       We'll continue to learn Python tomorrow.
# string                  str       We're going to learng Python in QF 627!
# string_PE_ratio         str       6.25
# string_example          str       We are using Python for e<...>ing our financial models!
# string_sample           str       We are now learning Python :)
# v1                      str       second string
# v2                      str       first string

# %% [markdown]
# ### The very first function that you should learn when you learn Python
#
# > `dir()`

# %%
dir(caps) # returns available attributes under the object
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(caps.lower)
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.

# %%
caps.lower?
# Out:
# Signature: caps.lower()
# Docstring: Return a copy of the string converted to lowercase.
# Type:      builtin_function_or_method

# %%
caps.lowerpy?
# Out:
# Object `caps.lowerpy` not found.

# %%
caps.lower??
# Out:
# Signature: caps.lower()
# Docstring: Return a copy of the string converted to lowercase.
# Type:      builtin_function_or_method

# %%
# print("Hello World :)")

# %% [markdown]
# >Convert it to lowercase.

# %%
caps.lower()
# Out:
# 'python'

# %%
# %whos
# Out:
# Variable                Type      Data/Info
# -------------------------------------------
# PE_ratio                float     62.5
# another_sample_object   int       11
# antigravity             module    <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# caps                    str       PYTHON
# earnigns                int       40
# float                   float     627.0
# float_example           float     11.0
# interim_object          str       first string
# object                  int       627
# our_sample_object       str       11
# price                   int       250
# sample                  int       55
# sample_string           str       python
# sample_string_to_test   str       We'll continue to learn Python tomorrow.
# string                  str       We're going to learng Python in QF 627!
# string_PE_ratio         str       6.25
# string_example          str       We are using Python for e<...>ing our financial models!
# string_sample           str       We are now learning Python :)
# v1                      str       second string
# v2                      str       first string

# %% [markdown]
# >Convert it to uppercase.

# %%
dir(sample_string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(sample_string.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
sample_string.upper()
# Out:
# 'PYTHON'

# %% [markdown]
# > Concatenate strings. We've sort of done this above.

# %%
sample_string + caps
# Out:
# 'pythonPYTHON'

# %%
(sample_string + caps).lower()
# Out:
# 'pythonpython'

# %%
(sample_string + caps).lower()
# Out:
# 'pythonpython'

# %%
(sample_string + " " + caps).lower()
# Out:
# 'python python'

# %%
concatenated_string = (sample_string + caps).lower()
concatenated_string
# Out:
# 'pythonpython'

# %%
help(concatenated_string.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
concatenated_string.replace("n", "n ", 1)
# Out:
# 'python python'

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# > shift + `l`: `l`ine number

# %%
# without_line_concat =
# "this will return an error"

# %%
with_line_concat =\
"this will work :)"

# %%
with_line_concat
# Out:
# 'this will work :)'

# %% [markdown]
# > Team, there are two ways of writing codes.
#
# ```python
# # Method 1
# concatenated_string_with_empty_space = (sample_string + caps).lower().replace("n", "n_", 1)
#
# # Method 2 --> yay!
# concatednated_string_with_empty_space =\
# (
#     (sample_string + caps)
#     .lower()
#     .replace("n", "n ", 1)
# )

# %%
### How to write Python code --> flow programming; chaining

# concatenated_string_with_empty_space = (sample_string + caps).lower().replace(old = "n", new = "n_", count = 1)

concatednated_string_with_empty_space =\
(
    (sample_string + caps)
    .lower()
    .replace("n", "n ", 1)
)

concatednated_string_with_empty_space
# Out:
# 'python python'

# %% [markdown]
# >Split strings.

# %%
# %whos
# Out:
# Variable                                Type      Data/Info
# -----------------------------------------------------------
# PE_ratio                                float     62.5
# another_sample_object                   int       11
# antigravity                             module    <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# caps                                    str       PYTHON
# concatednated_string_with_empty_space   str       python python
# concatenated_string                     str       pythonpython
# earnigns                                int       40
# float                                   float     627.0
# float_example                           float     11.0
# interim_object                          str       first string
# object                                  int       627
# our_sample_object                       str       11
# price                                   int       250
# sample                                  int       55
# sample_string                           str       python
# sample_string_to_test                   str       We'll continue to learn Python tomorrow.
# string                                  str       We're going to learng Python in QF 627!
# string_PE_ratio                         str       6.25
# string_example                          str       We are using Python for e<...>ing our financial models!
# string_sample                           str       We are now learning Python :)
# this                                    module    <module 'this' from '/Use<...>v/lib/python3.9/this.py'>
# v1                                      str       second string
# v2                                      str       first string
# with_line_concat                        str       this will work :)

# %%
string \
    .split("F")
# Out:
# ["We're going to learng Python in Q", ' 627!']

# %% [markdown]
# >Join a list of strings

# %%
"F"\
.join(
    ["We're going to learng Python in Q", ' 627!']
        )
# Out:
# "We're going to learng Python in QF 627!"

# %% [markdown]
# >Let's remove a character--note that it's space sensitive.

# %%
string.replace(" ", "")
# Out:
# "We'regoingtolearngPythoninQF627!"

# %%
string.replace(" ", "_")
# Out:
# "We're_going_to_learng_Python_in_QF_627!"

# %%
string.replace("g", "", 3)
# Out:
# "We're oin to learn Python in QF 627!"

# %% [markdown]
# >Strip whitespace.

# %%
sample_ws = "         HELLO             "

# %%
# %whos
# Out:
# Variable                                Type      Data/Info
# -----------------------------------------------------------
# PE_ratio                                float     62.5
# another_sample_object                   int       11
# antigravity                             module    <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# caps                                    str       PYTHON
# concatednated_string_with_empty_space   str       python python
# concatenated_string                     str       pythonpython
# earnigns                                int       40
# float                                   float     627.0
# float_example                           float     11.0
# interim_object                          str       first string
# object                                  int       627
# our_sample_object                       str       11
# price                                   int       250
# sample                                  int       55
# sample_string                           str       python
# sample_string_to_test                   str       We'll continue to learn Python tomorrow.
# sample_ws                               str                HELLO
# string                                  str       We're going to learng Python in QF 627!
# string_PE_ratio                         str       6.25
# string_example                          str       We are using Python for e<...>ing our financial models!
# string_sample                           str       We are now learning Python :)
# this                                    module    <module 'this' from '/Use<...>v/lib/python3.9/this.py'>
# v1                                      str       second string
# v2                                      str       first string
# with_line_concat                        str       this will work :)

# %% [markdown]
# >Removes only leading whitespace characters.

# %%
sample_ws \
    .lstrip()
# Out:
# 'HELLO             '

# %% [markdown]
# >Removes only trailing whitespace chars.

# %%
sample_ws \
    .rstrip()
# Out:
# '         HELLO'

# %%
sample_ws\
    .strip()
# Out:
# 'HELLO'

# %%
dir(sample_ws)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(sample_ws.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %% [markdown]
# ### Here, you will `learn` how to `learn` (no pun intended)
#
# >When you need `help remembering what methods` your variable has available.

# %%
dir(627)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %% [markdown]
# >When you need `help on a specific method`.

# %% [markdown]
# ###  `Debugging` Tips
#
# - Don't panic
# - read from the bottom
# - learn the rules (= google the error)
# - use `print` statements in places where variables are created or changed

# %% [markdown]
# Remember the following line of the code?

# %%
string_to_fix = 'I\'ll use it for extracting, wrangling, managing, and analyzing my financial data.'

# %% [markdown]
# ### `Identifying ErrorName` will be a good starting point :)
#
# | ErrorName | Example | Description (non-exhaustive) |
# | --- | --- | --- |
# | SyntaxError | 1) stocks = ["AAPL", "MSFT", "GOOGL" | Forgetting to close quotes and parentheses |
# | ValueError | int("AAPL") | Assiging an inappropriate value |
# | NameError | stocks = ["AAPL", "MSFT", "GOOGL"];print(stokcs) | A particular variable name is not found |

# %% [markdown]
# |A   |B   |
# |----|----|
# |cats|dogs|

# %% [markdown]
# ### Integers

# %% [markdown]
# >Let's create an integer.

# %%
my_integer = 25

# %% [markdown]
# >Print your integer.

# %%
print(my_integer)
# Out:
# 25

# %% [markdown]
# >Let's get the type of your integer.

# %%
type(my_integer)
# Out:
# int

# %% [markdown]
# >Do some addition.

# %%
my_sum = my_integer + 10
print(my_sum)
# Out:
# 35

# %% [markdown]
# >Do some subtraction.

# %%
my_difference = my_integer - 10
print(my_difference)
# Out:
# 15

# %% [markdown]
# >Do some multiplication.

# %%
my_product = my_integer * 10
print(my_product)
# Out:
# 250

# %% [markdown]
# >Do some division.

# %%
my_quotient = my_integer / 10
print(my_quotient)
# Out:
# 2.5

# %%
dir(my_quotient)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setformat__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
help(my_quotient.hex)
# Out:
# Help on built-in function hex:
#
# hex() method of builtins.float instance
#     Return a hexadecimal representation of a floating-point number.
#
#     >>> (-0.1).hex()
#     '-0x1.999999999999ap-4'
#     >>> 3.14159.hex()
#     '0x1.921f9f01b866ep+1'

# %% [markdown]
# ### Floats

# %% [markdown]
# >Let's create a float, assign it a value and print it.

# %%
my_float = 25.345
print(my_float)
# Out:
# 25.345

# %% [markdown]
# > Let's divide a float in half.

# %%
23.46/2
# Out:
# 11.73

# %% [markdown]
# >Please divide an integer in half.

# %%
5/2
# Out:
# 2.5

# %% [markdown]
# ## Data Structures

# %% [markdown]
# ### Lists

# %% [markdown]
# > You might want to create `a variable that includes several items`, like a list of numbers.
#
# > For that, Python uses `lists`: surrounded by square brackets and separated by commas.
#
# > You might think of it as a single row in Excel.
#
# > Each item in a Python list takes an ordered position called an index.
#
# > You can use the integer representing the index position inside the square brackets for `indexing`.

# %% [markdown]
# >Now let's create a list.

# %%
a_list =\
    [1, 
     2, 
     3]

print(a_list)
# Out:
# [1, 2, 3]

# %%
dir(a_list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# > Let's move one step further.

# %%
list_of_ticker =\
    ["META", 
     "AAPL",
     "AMZN",
     "NFLX",
     "GOOG"]

# %%
len(list_of_ticker)
# Out:
# 5

# %% [markdown]
# > Notice what appears when we ask for list item No. 1 to be printed--it gets the second item.
#
# > It's important to note and remember that Python counts things starting a zero.
#
# > Yes, Python is `zero-indexed`.
#
# > Thus, the first element in a list has an index of 0, and the second element has an index of 1, and so on.
#
# > You may also add or delete items from a list.
#
# > And determine the length of the list.

# %%
list_of_ticker[0]
# Out:
# 'META'

# %%
print(list_of_ticker)
# Out:
# ['META', 'AAPL', 'AMZN', 'NFLX', 'GOOG']

# %%
list_of_ticker[2:-1]
# Out:
# ['AMZN', 'NFLX']

# %%
type(list_of_ticker)
# Out:
# list

# %% [markdown]
# Note that when we appended something, we used `parentheses`, NOT square brackets.

# %% [markdown]
# >When creating a list, you can use `strings`, `integers`, `variables`, and so on.

# %%
type(100) # int
# Out:
# int

# %%
type(1e6) # 1e6 scientific notation; exponents; float
# Out:
# float

# %%
list_example =\
    ["We",
     "love",
     "machine",
     "learning", # str
     True, # bool
     True,
     100, # int 
     1e6 # float
     ]

# %%
list_example\
    .append("QF627 Rocks!")

# %%
list_example
# Out:
# ['We',
#  'love',
#  'machine',
#  'learning',
#  True,
#  True,
#  100,
#  1000000.0,
#  'QF627 Rocks!']

# %% [markdown]
# >Let's print the list.

# %% [markdown]
# >Create a list of strings.

# %%
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October"]

# %% [markdown]
# >When you wish to print the first item in the list.

# %%
months[0] == "January"
# Out:
# True

# %% [markdown]
# >What if you wish to print the last item in the list (`negative indexing of lists`)?

# %%
months[-1] == months[10-1]
# Out:
# True

# %% [markdown]
# >You may print all items from 4 through the end. We call this `slicing`.
#
# >`Slicling` includes the start and up to (but NOT includuing) the end as follows:
#
# >`mylist[StartAt:EndBefore]`

# %%
print(months)
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October']

# %% [markdown]
# >Print the middle 4 items.

# %%
months[3:7] == months[3:-3]
# Out:
# True

# %%
months[3:-3]
# Out:
# ['April', 'May', 'June', 'July']

# %% [markdown]
# >Add an item to the list and see if it was added. See what's happening if you run this cell over and over again.

# %%
dir(months)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
months.append("November")

# %%
months
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November']

# %% [markdown]
# >Let's delete the last item in the list.

# %%
del(months[-1]
   )

# %%
months
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October']

# %% [markdown]
# > Slicing using negative list indexing?
#
# > Yes, you can!

# %%
months = months[ :-1]
months
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September']

# %%
# months.append(["November", "December"])

# months.extend(["November", "December"]
#              )

# %% [markdown]
# > Let's print the items from the start to the penultimate.
#
# > We can do extended slicing with lists.

# %%
help(months.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
months.pop()
# Out:
# 'September'

# %%
months
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August']

# %% [markdown]
# >Let's set the last value in the list to a variable.

# %%
last_value =\
(
    months
    .pop()
)

last_value
# Out:
# 'August'

# %%
months
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June', 'July']

# %% [markdown]
# > Slicing with `Steps` also can be done.
#
# > Sometimes you might want to subset every other month in our list months.
#
# > Here's the code that will help you skip some elements when slicing a list.
#
# > `mylist[StartAt:EndBefore:Step]`

# %%
months.append("September")

# %%
months
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'September']

# %%
assigned =\
(
    months
    .append("October")
)#[0:-1:2]

assigned

# %%
months
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'September',
#  'October']

# %%
months[0:-1:2]
# Out:
# ['January', 'March', 'May', 'July']

# %%
assigned

# %%
# %whos
# Out:
# Variable                                Type        Data/Info
# -------------------------------------------------------------
# PE_ratio                                float       62.5
# a_list                                  list        n=3
# another_sample_object                   int         11
# antigravity                             module      <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# assigned                                NoneType    None
# caps                                    str         PYTHON
# concatednated_string_with_empty_space   str         python python
# concatenated_string                     str         pythonpython
# earnigns                                int         40
# float                                   float       627.0
# float_example                           float       11.0
# interim_object                          str         first string
# last_value                              str         August
# list_example                            list        n=9
# list_of_ticker                          list        n=5
# months                                  list        n=9
# my_difference                           int         15
# my_float                                float       25.345
# my_integer                              int         25
# my_product                              int         250
# my_quotient                             float       2.5
# my_sum                                  int         35
# object                                  int         627
# our_sample_object                       str         11
# price                                   int         250
# sample                                  int         55
# sample_string                           str         python
# sample_string_to_test                   str         We'll continue to learn Python tomorrow.
# sample_ws                               str                  HELLO
# string                                  str         We're going to learng Python in QF 627!
# string_PE_ratio                         str         6.25
# string_example                          str         We are using Python for e<...>ing our financial models!
# string_sample                           str         We are now learning Python :)
# string_to_fix                           str         I'll use it for extractin<...>lyzing my financial data.
# this                                    module      <module 'this' from '/Use<...>v/lib/python3.9/this.py'>
# v1                                      str         second string
# v2                                      str         first string
# with_line_concat                        str         this will work :)

# %%
help(months.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
months.append?
# Out:
# Signature: months.append(object, /)
# Docstring: Append object to the end of the list.
# Type:      builtin_function_or_method

# %% [markdown]
# #### Lists in Lists
#
# - As you have learned above, lists can accomodate (contain) various data types
#
# - Lists can contain list themselves as well. We call this a `nested list`.
#
# > Let's have a look at a nested list describing the month and its associated consumer price index

# %%
# cpi_nested_list = [["August", "September", "October", "November"], [97.8, 98.9, 99.7, 100.5]]

cpi_nested_list =\
    [
        ["August", "September", "October", "November"], 
        [97.8,     98.9,        99.7,      100.5]
    ]

# %% [markdown]
# > Let's subset nested lists.
#
# > You can also extract an element from the list you extracted.
#
# > To do this, you use `two indices`.
#
# > The first index is the position of the list, and the second index is the position of the element within the list.

# %%
len(cpi_nested_list) == 2
# Out:
# True

# %% [markdown]
# ```python
# # NESTED LIST
# cpi_nested_list = [["August", "September", "October", "November"], [97.8, 98.9, 99.7, 100.5]]

# %%
98.9 == cpi_nested_list[1][1]
# Out:
# True

# %%
list_of_price=\
(
    cpi_nested_list
    .pop()
)

# %%
print(list_of_price);print(cpi_nested_list)
# Out:
# [97.8, 98.9, 99.7, 100.5]
# [['August', 'September', 'October', 'November']]

# %%
months.append(
        ["November", "December"]
             ) # inplace = True # returns None

# %%
# %whos
# Out:
# Variable                                Type        Data/Info
# -------------------------------------------------------------
# PE_ratio                                float       62.5
# a_list                                  list        n=3
# another_sample_object                   int         11
# antigravity                             module      <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# assigned                                NoneType    None
# caps                                    str         PYTHON
# concatednated_string_with_empty_space   str         python python
# concatenated_string                     str         pythonpython
# cpi_nested_list                         list        n=1
# earnigns                                int         40
# float                                   float       627.0
# float_example                           float       11.0
# interim_object                          str         first string
# last_value                              str         August
# list_example                            list        n=9
# list_of_price                           list        n=4
# list_of_ticker                          list        n=5
# months                                  list        n=10
# my_difference                           int         15
# my_float                                float       25.345
# my_integer                              int         25
# my_product                              int         250
# my_quotient                             float       2.5
# my_sum                                  int         35
# object                                  int         627
# our_sample_object                       str         11
# price                                   int         250
# sample                                  int         55
# sample_string                           str         python
# sample_string_to_test                   str         We'll continue to learn Python tomorrow.
# sample_ws                               str                  HELLO
# string                                  str         We're going to learng Python in QF 627!
# string_PE_ratio                         str         6.25
# string_example                          str         We are using Python for e<...>ing our financial models!
# string_sample                           str         We are now learning Python :)
# string_to_fix                           str         I'll use it for extractin<...>lyzing my financial data.
# this                                    module      <module 'this' from '/Use<...>v/lib/python3.9/this.py'>
# v1                                      str         second string
# v2                                      str         first string
# with_line_concat                        str         this will work :)

# %% [markdown]
# ### Methods and Functions

# %% [markdown]
# | Methods | Functions |
# | --- | --- |
# | All methods are functions | Not all functions are methods |
# | Acts on an object `months.append()` | Requires an input of an object `type(months)` |

# %% [markdown]
# > List methods are a subset of built-in functions in Python.

# %% [markdown]
#  #### Methods specific to list
#
#  - Lists have several built-in methods that can help retrieve and manipulate data
#  - Methods can be accessed as `list.method()`
#  - `list_sort()` sorts list elements in ascending order.

# %%
# %whos
# Out:
# Variable                                Type        Data/Info
# -------------------------------------------------------------
# PE_ratio                                float       62.5
# a_list                                  list        n=3
# another_sample_object                   int         11
# antigravity                             module      <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# assigned                                NoneType    None
# caps                                    str         PYTHON
# concatednated_string_with_empty_space   str         python python
# concatenated_string                     str         pythonpython
# cpi_nested_list                         list        n=1
# earnigns                                int         40
# float                                   float       627.0
# float_example                           float       11.0
# interim_object                          str         first string
# last_value                              str         August
# list_example                            list        n=9
# list_of_price                           list        n=4
# list_of_ticker                          list        n=5
# months                                  list        n=10
# my_difference                           int         15
# my_float                                float       25.345
# my_integer                              int         25
# my_product                              int         250
# my_quotient                             float       2.5
# my_sum                                  int         35
# object                                  int         627
# our_sample_object                       str         11
# price                                   int         250
# sample                                  int         55
# sample_string                           str         python
# sample_string_to_test                   str         We'll continue to learn Python tomorrow.
# sample_ws                               str                  HELLO
# string                                  str         We're going to learng Python in QF 627!
# string_PE_ratio                         str         6.25
# string_example                          str         We are using Python for e<...>ing our financial models!
# string_sample                           str         We are now learning Python :)
# string_to_fix                           str         I'll use it for extractin<...>lyzing my financial data.
# this                                    module      <module 'this' from '/Use<...>v/lib/python3.9/this.py'>
# v1                                      str         second string
# v2                                      str         first string
# with_line_concat                        str         this will work :)

# %% [markdown]
# > Remember `list.append()`?
#
# > `list.append()` adds a single element to a list

# %%
list_of_ticker.append("NVDA")

list_of_ticker
# Out:
# ['META', 'AAPL', 'AMZN', 'NFLX', 'GOOG', 'NVDA']

# %%
list_of_ticker.append(["ZM", "CSCO"]
                     )
list_of_ticker
# Out:
# ['META', 'AAPL', 'AMZN', 'NFLX', 'GOOG', 'NVDA', ['ZM', 'CSCO']]

# %% [markdown]
# > `list.extend()` method increases the length by the number of elements that are provided to it.

# %%
list_of_ticker.extend(["ZM", "CSCO"]
                     )
list_of_ticker
# Out:
# ['META', 'AAPL', 'AMZN', 'NFLX', 'GOOG', 'NVDA', ['ZM', 'CSCO'], 'ZM', 'CSCO']

# %% [markdown]
# > `list.index(x)` returns the lowest index where the element x appears
#
# > That is, it returns the index of a specific element.

# %%
list_of_ticker\
    .index("ZM")
# Out:
# 7

# %% [markdown]
# > Now the corresponding price for July can be accesed using the index.

# %%
list_of_ticker[7] == "ZM"
# Out:
# True

# %% [markdown]
# > Here are some functions that will be uesful.
#
# > `min(list)` returns the smallest element
#
# > `max(list` returns the largest element
#
# > Let's find the month with largest consumer price index then.

# %%
months = ["June", "July", "August"] # vector
prices = [99.93, 99.5, 99.9] # vector
# vector + vector ==> matrix

# %% [markdown]
# > Additional `hot`keys
#
# - shift + ctrl + `-`: `split` the given cell
# - shift + `m`: `m`erge the chosen cells

# %%
# Identify max price
max_prices =\
    max(prices)

# %%
# Then, use Index method to identify the indexed location of the max_price
max_prices_index =\
(
    prices
    .index(max_prices)
)

# %%
# Using the indexed location on months, you can identify the month with the maximum consumer price index.
max_months =\
(
    months
    [max_prices_index]
)

max_months == "June"
# Out:
# True

# %% [markdown]
# ### ***Things to be cautious!***

# %% [markdown]
# #### 1. Note that some words are special or reserved in Python.
#
# We can't name our integer variable int or our float simply float.
#
# The same goes with the following words:
#
# `and`	`as`	`assert`
#
# `break`
#
# `class` `continue`
#
# `def`	`del`
#
# `elif`	`else`	`except`
#
# `False` `finally` `for`	`from`
#
# `global`
#
# `if`	`import`	`in`	`is`
#
# `lambda`
#
# `None`	`nonlocal`	`not`
#
# `or`
#
# `pass`
#
# `raise`	`return`
#
# `True`	`try`	`while`	`with`
#
# `yield`
#
# #### 2. ==
#
# Note the double equal ==.
#
# That's the Python equivalent for a single on your calculator.
#
# #### 3. !=
#
# And != is the equivalent of not equal.
#
# #### 4. Python is an `indententation-sensitive` langauge.
#
# And note the `indentation`--it's `four spaces`, and it's `important for Python`.
#
# Some text editors (Jupyter Notebook or Sublime Text, for instance) will automatically indent properly.
#
# But not all tabs are four spaces. So use caution!
#
# #### 5. Capitalization of `True` and `False`
#
# Also note the capitalization of True and False.
#
# And the fact that those reserved/special words show up as green.

# %% [markdown]
# ### Booleans

# %% [markdown]
# > `==` equal
#
# > `!=` does not equal
#
# > `>` greater than
#
# > `<` less than

# %% [markdown]
# >Create two variables, assign values and compare them.

# %%
x = 5
y = 15

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x > y
# Out:
# False

# %%
x >= y
# Out:
# False

# %%
x < y
# Out:
# True

# %%
x <= y
# Out:
# True

# %% [markdown]
# > Create two variables, assign one as a number and one as a string and compare them.

# %%
z = 10
v = "10"
z == v
# Out:
# False

# %% [markdown]
# ### `if else` Statements

# %%
q = "627"
f = "627"

# %%
f = 627

# %%
if q == f:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# > Please write the following.
# > `If x is greater than y, print my_list. Otherwise, print my_dict.`

# %% [markdown]
# ### Customized Function

# %%
6 * 2 * 7
# Out:
# 84

# %%
# use action verb for naming of your function
def run_multiplication(x, y, z):
    return x * y * z

# %%
# %whos
# Out:
# Variable                                Type        Data/Info
# -------------------------------------------------------------
# PE_ratio                                float       62.5
# a_list                                  list        n=3
# another_sample_object                   int         11
# antigravity                             module      <module 'antigravity' fro<...>ython3.9/antigravity.py'>
# assigned                                NoneType    None
# caps                                    str         PYTHON
# concatednated_string_with_empty_space   str         python python
# concatenated_string                     str         pythonpython
# cpi_nested_list                         list        n=1
# earnigns                                int         40
# f                                       int         627
# float                                   float       627.0
# float_example                           float       11.0
# interim_object                          str         first string
# last_value                              str         August
# list_example                            list        n=9
# list_of_price                           list        n=4
# list_of_ticker                          list        n=9
# max_months                              str         June
# max_prices                              float       99.93
# max_prices_index                        int         0
# months                                  list        n=3
# my_difference                           int         15
# my_float                                float       25.345
# my_integer                              int         25
# my_product                              int         250
# my_quotient                             float       2.5
# my_sum                                  int         35
# object                                  int         627
# our_sample_object                       str         11
# price                                   int         250
# prices                                  list        n=3
# q                                       str         627
# run_multiplication                      function    <function run_multiplication at 0x106168430>
# sample                                  int         55
# sample_string                           str         python
# sample_string_to_test                   str         We'll continue to learn Python tomorrow.
# sample_ws                               str                  HELLO
# string                                  str         We're going to learng Python in QF 627!
# string_PE_ratio                         str         6.25
# string_example                          str         We are using Python for e<...>ing our financial models!
# string_sample                           str         We are now learning Python :)
# string_to_fix                           str         I'll use it for extractin<...>lyzing my financial data.
# this                                    module      <module 'this' from '/Use<...>v/lib/python3.9/this.py'>
# v                                       str         10
# v1                                      str         second string
# v2                                      str         first string
# with_line_concat                        str         this will work :)
# x                                       int         5
# y                                       int         15
# z                                       int         10

# %%
run_multiplication(6,2,7)
# Out:
# 84

# %% [markdown]
# One other basic concept that typically combines many of these elements is a function.
#
# You might use a series of functions (building blocks) to achieve your programming goals.
#
# Here's an example of one

# %% [markdown]
# ### Loops
#
# We've done an `if/else` conditional statement.
#
# We can also control what we're getting from files, URLs or other code by using `for` loops.
#
# For (again, no pun intended) instance, instead of using individual print statements (tedious, especially if you misspell pring, I mean, print, all the time), you can use a loop to call each item in the list.
#
# Here's the thinking behind a for loop in what's called pseudocode.
#
# This is a good way to draft out what you're trying to do with your code::
#
# for each item in the list:
# - do something
# - maybe another thing
# - maybe more stuff even
#
# Let's try it with my_list.

# %%
list_example
# Out:
# ['We',
#  'love',
#  'machine',
#  'learning',
#  True,
#  True,
#  100,
#  1000000.0,
#  'QF627 Rocks!']

# %%
print(list_example[0]
     )
# Out:
# We

# %%
print(list_example[1]
     )
# Out:
# love

# %%
print(list_example[-1]
     )
# Out:
# QF627 Rocks!

# %%
print(list_example[0]);print(list_example[1]);print(list_example[-1])
# Out:
# We
# love
# QF627 Rocks!

# %% [markdown]
# > Let's take your list or make a new one, loop through it printing out each value.

# %%
for each_element in list_example:
    print(each_element)
# Out:
# We
# love
# machine
# learning
# True
# True
# 100
# 1000000.0
# QF627 Rocks!

# %%
for each_element in list_example[3:-3:2]:
    print(each_element)
# Out:
# learning
# True

# %% [markdown]
# ### Pythonian Data Structure ==> dictionary (`dict`)

# %% [markdown]
# How about a loop that prints sentences of they key and the value in `person_data`?
#
# We'll add white space, use addition, and rememer when you need quote marks.

# %% [markdown]
# > dict{`key`:`value`}

# %%
person_data_dict =\
    {"first name": "Prakash",
     "family name": "Nirala",
     "country": "India",
     "favorite subject": "Recurrent Neural Networks"}

# %%
type(person_data_dict)
# Out:
# dict

# %% [markdown]
# > Again, it's a pretty straight forward concept.

# %%
for key in (person_data_dict):
    print("The key is " 
          + 
          key 
          + 
          " and the value is "
          + 
          person_data_dict[key] 
          +
          ":)"
         )
# Out:
# The key is first name and the value is Prakash:)
# The key is family name and the value is Nirala:)
# The key is country and the value is India:)
# The key is favorite subject and the value is Recurrent Neural Networks:)

# %% [markdown]
# ### How to write `mathematical notations and formula` (A Quick Guide)

# %% [markdown]
# $$
#     \hat{Y}_i = \hat{\beta}_0 + \sum \limits _{j=1} ^{p} X_{ij}\hat{\beta}_{j}
# $$

# %% [markdown]
# > So, this is just a taste of Python.
#
# > This barely skims the surface of what you can do in Python, but hopefully this overview will make you comfortable enough to get started and to give you a sense of the language, along with how `Jupyter Notebook` is used.
#
# > Speaking of Jupyter Notebook, note that the default autosave interval in Jupyter notebook is 120 seconds. You can change this with the `%autosave` magic command for an individual notebook like this:

# %% [markdown]
# > **One more thing to share, before you go.**
#
# > Jupyter Notebook creates a `checkpoint` file every single time you create an .ipynb file, and then it updates the checkpoint file every single time you manually save your progress for the initial .ipynb.
#
# > A manual save is what's done when the file is saved by clicking the Save and Checkpoint button.
#
# > As a side note, the checkpoint file is located within a hidden folder named .ipynb_checkpoints. This folder is located within the same folder as the initial .ipynb file.

# %% [markdown]
# ### Absolute last thing, before you go.

# %% [markdown]
# >Now, let's indeed exit the program.

# %% [markdown]
# `Thank you for working with the script.`
