# %% [markdown]
# # QF 627 Programming and Computational Finance
# ## `Py`Day Week `1` | Problem-Sets for Exercise 0 | `RE`view

# %% [markdown]
# > Hi Team,
#
# > The current document contains `exercise questions` to help you to consolidate your learning up to this point.
#
# > On the one hand, this will be a `good revision` of what you `have learned` from the lessons (and assigned readings). On the other hand, these exercise questions are also designed as a `pathway to your learning` in the `upcoming lessons`.
#
# > It may be that you cannot answer every question. If you are unsure about how to answer a question, `look for clues` in the `review scripts` and `assigned readings`.
#
# > For each question, please make sure to assign your answers into objects. Here is our convention for the current assignment. For your answer to each question, please `use capital letter A`, `followed by the numerical value of the question`—that is, if you store your `answer to Question 1`, then it should be an object named `A1`.
#
# > Upon completion of your work, please `submit` your `.ipynb` file via eLearn.

# %% [markdown]
# ### Please import necessary packages (modules, libraries; i.e., `numpy`, `matplotlib`, and `pandas`)

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# np         module    <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# pd         module    <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>

# %% [markdown]
# ### Question 1. Under the `Problem-sets for Exercise` tab you will find 12 CSV files. Please read the 12 CSV files. Then, please merge the 12 CSV files into a single dataset.

# %%
# %ls
# Out:
# 2016_census_data.csv
# Exercise_Data_April.csv
# Exercise_Data_August.csv
# Exercise_Data_December.csv
# Exercise_Data_February.csv
# Exercise_Data_January.csv
# Exercise_Data_July.csv
# Exercise_Data_June.csv
# Exercise_Data_March.csv
# Exercise_Data_May.csv
# Exercise_Data_November.csv
# Exercise_Data_October.csv
# Exercise_Data_September.csv
# QF627_Exercise_Problem_Sets_1.ipynb
# QF627_G2_CourseSyllabus_2024.docx
# QF627_G2_CourseSyllabus_2024.pdf
# QF627_Lesson01_Revisit_Numpy_Pandas_Matplotlib_Part1.ipynb
# QF627_PreCourse_01_Introduction_REview.ipynb
# QF627_PreCourse_02_NumPy_REview.ipynb
# QF627_PreCourse_03_matplotlib_REview.ipynb
# QF627_PreCourse_04_pandas_Part1_REview.ipynb
# QF627_PreCourse_04_pandas_Part2_REview.ipynb
# QF627_PreCourse_Problem_Sets.ipynb
# QF627_Random_Grouping.ipynb
# accidents.csv
# countries.csv
# matplotlib.png
# ndim.png
# players.csv
# plot_with_shapes.png
# qf627_g2.csv
# salaries.csv
# ted.csv
# top10_players.csv

# %%
# Method 0

# months =\
#     ["January",
#      "February"
#      ...]

# %%
# Method 1

import os

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# np         module    <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# os         module    <module 'os' from '/Users<...>nv/lib/python3.10/os.py'>
# pd         module    <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>

# %%
(
    pd
    .DataFrame(np.array(os.listdir()
                       ),
               columns = ["filename"]
               )
)
# Out:
#                                              filename
# 0        QF627_PreCourse_04_pandas_Part2_REview.ipynb
# 1                                             ted.csv
# 2                                        salaries.csv
# 3                           Exercise_Data_January.csv
# 4        QF627_PreCourse_01_Introduction_REview.ipynb
# 5                 QF627_Exercise_Problem_Sets_1.ipynb
# 6                    QF627_G2_CourseSyllabus_2024.pdf
# 7                                           .DS_Store
# 8                          Exercise_Data_February.csv
# 9                                       countries.csv
# 10                            Exercise_Data_April.csv
# 11                            Exercise_Data_March.csv
# 12                                      accidents.csv
# 13                                  top10_players.csv
# 14                           Exercise_Data_August.csv
# 15                 QF627_PreCourse_Problem_Sets.ipynb
# 16                         Exercise_Data_December.csv
# 17         QF627_PreCourse_03_matplotlib_REview.ipynb
# 18                         Exercise_Data_November.csv
# 19                                       qf627_g2.csv
# 20                                     matplotlib.png
# 21  QF627_Lesson01_Revisit_Numpy_Pandas_Matplotlib...
# 22              QF627_PreCourse_02_NumPy_REview.ipynb
# 23                                        players.csv
# 24                          Exercise_Data_October.csv
# 25                               plot_with_shapes.png
# 26                             Exercise_Data_June.csv
# 27                  QF627_G2_CourseSyllabus_2024.docx
# 28                               2016_census_data.csv
# 29                             Exercise_Data_July.csv
# 30                                 .ipynb_checkpoints
# 31                        QF627_Random_Grouping.ipynb
# 32       QF627_PreCourse_04_pandas_Part1_REview.ipynb
# 33                              Exercise_Data_May.csv
# 34                        Exercise_Data_September.csv
# 35                                           ndim.png

# %%
list_of_filenames =\
    [file for file in os.listdir(".") if file.startswith("Exercise_Data_")
    ]

list_of_filenames
# Out:
# ['Exercise_Data_January.csv',
#  'Exercise_Data_February.csv',
#  'Exercise_Data_April.csv',
#  'Exercise_Data_March.csv',
#  'Exercise_Data_August.csv',
#  'Exercise_Data_December.csv',
#  'Exercise_Data_November.csv',
#  'Exercise_Data_October.csv',
#  'Exercise_Data_June.csv',
#  'Exercise_Data_July.csv',
#  'Exercise_Data_May.csv',
#  'Exercise_Data_September.csv']

# %%
a1_solution1 =\
(
    pd
    .DataFrame()
)

for f in list_of_filenames:
    
    read_data =\
        pd\
        .read_csv(f)
    
    a1_solution1 =\
        pd\
        .concat([a1_solution1,
                 read_data]
               )

a1_solution1
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1      01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2      01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3      01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4      01/25/19 11:59            387 10th St, Austin, TX 73301
# ...               ...                                      ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
# Solution 2

import calendar

# %%
# %whos
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# a1_solution1        DataFrame          Order ID           <...>[186850 rows x 6 columns]
# calendar            module       <module 'calendar' from '<...>/python3.10/calendar.py'>
# f                   str          Exercise_Data_September.csv
# list_of_filenames   list         n=12
# np                  module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# os                  module       <module 'os' from '/Users<...>nv/lib/python3.10/os.py'>
# pd                  module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# plt                 module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# read_data           DataFrame          Order ID           <...>n[11686 rows x 6 columns]

# %%
months_list =\
    list(calendar
         .month_name)[1: ]

# %%
months_list
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
months_list_TWINS =\
(
    pd
    .date_range(start = "2024-01-01",
                periods = 12,
                freq = "M")
    .month_name()
    .to_list()
)

months_list_TWINS == months_list
# Out:
# True

# %%
np.array(months_list_TWINS) == np.array(months_list)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
a1_solution2 = []

for each_element in months_list:
    a1_solution2\
        .append(pd
                .read_csv("Exercise_Data_" + str(each_element) + ".csv")
               )

a1_solution2 =\
(
    pd
    .concat(a1_solution2,
            ignore_index = True)
)

# %%
a1_solution2
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# 0       01/22/19 21:25         944 Walnut St, Boston, MA 02215
# 1       01/28/19 14:15        185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33   538 Adams St, San Francisco, CA 94016
# 3       01/05/19 20:33      738 10th St, Los Angeles, CA 90001
# 4       01/25/19 11:59           387 10th St, Austin, TX 73301
# ...                ...                                     ...
# 186845  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 186846  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 186847  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 186848  12/03/19 10:39          778 River St, Dallas, TX 75001
# 186849  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [186850 rows x 6 columns]

# %%
# method 3

import glob # matching patterns from filenames

target_files =\
    glob\
    .glob("Exercise_Data*.csv")

DF = []

for each_file in target_files:
    placeholder = pd.read_csv(each_file)
    DF.append(placeholder)

a1_solution3 =\
(
    pd
    .concat(DF,
            axis = 0,
            ignore_index = True)
)

a1_solution3
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   259353    AAA Batteries (4-pack)                3       2.99
# 186846   259354                    iPhone                1        700
# 186847   259355                    iPhone                1        700
# 186848   259356    34in Ultrawide Monitor                1     379.99
# 186849   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 0       01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1       01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3       01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4       01/25/19 11:59            387 10th St, Austin, TX 73301
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %% [markdown]
# ### <font color="green">***Now let's clean up the dataset :)***</font>
#
# > The first step in this exercise is figuring out what we need to clean.

# %% [markdown]
# ### Question 2. Please remove rows of NAN

# %%
a1_solution2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
a1_solution2[a1_solution2
             .isna()
             .any(axis = 1)
            ].shape # (545, 6)
# Out:
# (545, 6)

# %%
a2 =\
(
    a1_solution2
    .dropna(how = "all")
)

a2.shape[0] + 545 == a1_solution2.shape[0]
# Out:
# True

# %% [markdown]
# ### Question 3. Please remove text in `Order Date` column

# %%
a2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
a2["filter_for_string"] =\
(
    a2 # DataFrame
    ["Order Date"] # target Series
    .str
    .match("([a-zA-Z\s])"
          )
)
# Bool
# Out:
# /var/folders/92/v3m3bh610pz80xs31zwcwtcc0000gn/T/ipykernel_5662/2899755721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a2["filter_for_string"] =\

# %%
a2.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered     object
# Price Each           object
# Order Date           object
# Purchase Address     object
# filter_for_string      bool
# dtype: object

# %%
a3 =\
    a2[a2["filter_for_string"] == False]

a3.shape[1] == 7
# Out:
# True

# %%
a3 =\
(
    a3
    .drop(["filter_for_string"],
          axis = 1)
)

a3.shape[1] == 6
# Out:
# True

# %%
a3.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# ### Question 4. Please make columns correct type: namely, make `Quantity Ordered` and `Price Each` as numeric data types.

# %%
a3.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
a3[['Quantity Ordered', 'Price Each']] =\
(
    a3
    [['Quantity Ordered', 'Price Each']]
    .apply(pd
           .to_numeric)
)

a3.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %%
a4 =\
(
    a3
    .copy()
)

# %% [markdown]
# ### <font color="green">***Let's create additional columns (variables) for your data exploration.</font>***

# %% [markdown]
# ### Question 5. Please add `Month` column: Create the `Month` from `Order Date` column

# %%
a4[["Order Date"]]
# Out:
#             Order Date
# 0       01/22/19 21:25
# 1       01/28/19 14:15
# 2       01/17/19 13:33
# 3       01/05/19 20:33
# 4       01/25/19 11:59
# ...                ...
# 186845  12/11/19 20:58
# 186846  12/01/19 12:01
# 186847  12/09/19 06:43
# 186848  12/03/19 10:39
# 186849  12/21/19 21:45
#
# [185950 rows x 1 columns]

# %%
a4["Month"] =\
(
    a4 # DataFrame
    ["Order Date"] # Series
    .str
    [0:2]
    .astype("int64")
)

a4.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int64
# dtype: object

# %%
a5 =\
(
    a4
    .copy()
)

# %% [markdown]
# ### Question 6. Please add `City` column: Create the `City` from `Purchase Address` column

# %%
a5.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month'],
#       dtype='object')

# %%
a5[["Purchase Address"]]
# Out:
#                               Purchase Address
# 0              944 Walnut St, Boston, MA 02215
# 1             185 Maple St, Portland, OR 97035
# 2        538 Adams St, San Francisco, CA 94016
# 3           738 10th St, Los Angeles, CA 90001
# 4                387 10th St, Austin, TX 73301
# ...                                        ...
# 186845  14 Madison St, San Francisco, CA 94016
# 186846    549 Willow St, Los Angeles, CA 90001
# 186847        273 Wilson St, Seattle, WA 98101
# 186848          778 River St, Dallas, TX 75001
# 186849  747 Chestnut St, Los Angeles, CA 90001
#
# [185950 rows x 1 columns]

# %%
a5["Purchase Address"]
# Out:
# 0                944 Walnut St, Boston, MA 02215
# 1               185 Maple St, Portland, OR 97035
# 2          538 Adams St, San Francisco, CA 94016
# 3             738 10th St, Los Angeles, CA 90001
# 4                  387 10th St, Austin, TX 73301
#                            ...
# 186845    14 Madison St, San Francisco, CA 94016
# 186846      549 Willow St, Los Angeles, CA 90001
# 186847          273 Wilson St, Seattle, WA 98101
# 186848            778 River St, Dallas, TX 75001
# 186849    747 Chestnut St, Los Angeles, CA 90001
# Name: Purchase Address, Length: 185950, dtype: object

# %%
a5["interim_string"] =\
(
    a5["Purchase Address"]
    .astype("string")
    .str
    .split(",")# delim
)

a5["interim_string"]
# Out:
# 0                [944 Walnut St,  Boston,  MA 02215]
# 1               [185 Maple St,  Portland,  OR 97035]
# 2          [538 Adams St,  San Francisco,  CA 94016]
# 3             [738 10th St,  Los Angeles,  CA 90001]
# 4                  [387 10th St,  Austin,  TX 73301]
#                              ...
# 186845    [14 Madison St,  San Francisco,  CA 94016]
# 186846      [549 Willow St,  Los Angeles,  CA 90001]
# 186847          [273 Wilson St,  Seattle,  WA 98101]
# 186848            [778 River St,  Dallas,  TX 75001]
# 186849    [747 Chestnut St,  Los Angeles,  CA 90001]
# Name: interim_string, Length: 185950, dtype: object

# %%
type(a5["interim_string"]
    )
# Out:
# pandas.core.series.Series

# %%
type(a5["interim_string"][0]
    )
# Out:
# list

# %%
a5["interim_string"][2][1]

# %%
a5["interim_string"][2][1]\
    .strip(" ")
# Out:
# 'San Francisco'

# %%
# build a function, using lambda keyword

addition = lambda x, y: x + y

addition(x = 6, y = 2) == 6 + 2
# Out:
# True

# %%
def repeat_WoW(WoW, repeat):
    WoWs = WoW * repeat
    return WoWs

# %%
# %whos
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# DF                  list         n=12
# a1_solution1        DataFrame          Order ID           <...>[186850 rows x 6 columns]
# a1_solution2        DataFrame           Order ID          <...>[186850 rows x 6 columns]
# a1_solution3        DataFrame           Order ID          <...>[186850 rows x 6 columns]
# a2                  DataFrame           Order ID          <...>[186305 rows x 7 columns]
# a3                  DataFrame           Order ID          <...>[185950 rows x 6 columns]
# a4                  DataFrame           Order ID          <...>[185950 rows x 7 columns]
# a5                  DataFrame           Order ID          <...>[185950 rows x 8 columns]
# addition            function     <function <lambda> at 0x13ffe7f40>
# calendar            module       <module 'calendar' from '<...>/python3.10/calendar.py'>
# each_element        str          December
# each_file           str          Exercise_Data_September.csv
# f                   str          Exercise_Data_September.csv
# glob                module       <module 'glob' from '/Use<...>/lib/python3.10/glob.py'>
# list_of_filenames   list         n=12
# months_list         list         n=12
# months_list_TWINS   list         n=12
# np                  module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# os                  module       <module 'os' from '/Users<...>nv/lib/python3.10/os.py'>
# pd                  module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# placeholder         DataFrame          Order ID           <...>n[11686 rows x 6 columns]
# plt                 module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# read_data           DataFrame          Order ID           <...>n[11686 rows x 6 columns]
# repeat_WoW          function     <function repeat_WoW at 0x12f8eae60>
# target_files        list         n=12

# %%
repeat_WoW("WoW!", 27)
# Out:
# 'WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!WoW!'

# %%
mqf_course = lambda prefix, suffix: f"qf 627: {prefix.title()} {suffix.title()}"
mqf_course("computational", "finance")
# Out:
# 'qf 627: Computational Finance'

# %%
a5["interim_string"]
# Out:
# 0                [944 Walnut St,  Boston,  MA 02215]
# 1               [185 Maple St,  Portland,  OR 97035]
# 2          [538 Adams St,  San Francisco,  CA 94016]
# 3             [738 10th St,  Los Angeles,  CA 90001]
# 4                  [387 10th St,  Austin,  TX 73301]
#                              ...
# 186845    [14 Madison St,  San Francisco,  CA 94016]
# 186846      [549 Willow St,  Los Angeles,  CA 90001]
# 186847          [273 Wilson St,  Seattle,  WA 98101]
# 186848            [778 River St,  Dallas,  TX 75001]
# 186849    [747 Chestnut St,  Los Angeles,  CA 90001]
# Name: interim_string, Length: 185950, dtype: object

# %%
def CITY(address):
    return address.split(",")[1].strip(" ")

# %%
def STATE(address):
    return address.split(",")[2].split(" ")[1]

# %%
a5["city_state"] =\
(
    a5
    ["Purchase Address"]
    .apply(lambda x: f"{CITY(x)} {STATE(x)}")
)

# %%
a5[["city_state"]] # DataFrame
# Out:
#               city_state
# 0              Boston MA
# 1            Portland OR
# 2       San Francisco CA
# 3         Los Angeles CA
# 4              Austin TX
# ...                  ...
# 186845  San Francisco CA
# 186846    Los Angeles CA
# 186847        Seattle WA
# 186848         Dallas TX
# 186849    Los Angeles CA
#
# [185950 rows x 1 columns]

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from requests->folium) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sroh/miniforge3/envs/rohenv/lib/python3.10/site-packages (from requests->folium) (2024.7.4)

# %%
import folium

# %%
(
    folium
    .Map(location = [1.3521, 103.8198],
         zoom_start = 12
        )
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5623eacb750c66c4f7359c47484593b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5623eacb750c66c4f7359c47484593b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5623eacb750c66c4f7359c47484593b2 = L.map(
#                 &quot;map_5623eacb750c66c4f7359c47484593b2&quot;,
#                 {
#                     center: [1.3521, 103.8198],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efa50ac6b2263fa3322f91e0412c5cb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_efa50ac6b2263fa3322f91e0412c5cb3.addTo(map_5623eacb750c66c4f7359c47484593b2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a6 =\
(
    a5
    .copy()
)

# %% [markdown]
# ### <font color="green">***Now, let's explore our data***</font>

# %% [markdown]
# ### Question 7: What was the best month for the business? How much was earned that month? Please use `Quantity Ordered` and `Price Each` columns to create a new column (variable) `Gross Revenue`.

# %%
a6.head(4)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
#
#        Order Date                       Purchase Address  Month  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1
#
#                               interim_string        city_state
# 0        [944 Walnut St,  Boston,  MA 02215]         Boston MA
# 1       [185 Maple St,  Portland,  OR 97035]       Portland OR
# 2  [538 Adams St,  San Francisco,  CA 94016]  San Francisco CA
# 3     [738 10th St,  Los Angeles,  CA 90001]    Los Angeles CA

# %%
a6["Gross Revenue"] =\
    a6["Quantity Ordered"] * a6["Price Each"]

a6.head(3)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
#
#        Order Date                       Purchase Address  Month  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1
#
#                               interim_string        city_state  Gross Revenue
# 0        [944 Walnut St,  Boston,  MA 02215]         Boston MA         700.00
# 1       [185 Maple St,  Portland,  OR 97035]       Portland OR          14.95
# 2  [538 Adams St,  San Francisco,  CA 94016]  San Francisco CA          23.98

# %%
(
    a6
    [["Gross Revenue"]]
    .describe()
).T
# Out:
#                   count        mean         std   min    25%    50%    75%  \
# Gross Revenue  185950.0  185.490917  332.919771  2.99  11.95  14.95  150.0
#
#                   max
# Gross Revenue  3400.0

# %%
(
    a6
    .groupby(["Month"]
            )
    .sum() # .mean() # .median()
    [["Gross Revenue", "Quantity Ordered", "Price Each"]]
)
# Out:
#        Gross Revenue  Quantity Ordered  Price Each
# Month
# 1         1822256.73             10903  1811768.38
# 2         2202022.42             13449  2188884.72
# 3         2807100.38             17005  2791207.83
# 4         3390670.24             20558  3367671.02
# 5         3152606.75             18667  3135125.13
# 6         2577802.26             15253  2562025.61
# 7         2647775.76             16072  2632539.56
# 8         2244467.88             13448  2230345.42
# 9         2097560.13             13109  2084992.09
# 10        3736726.88             22703  3715554.83
# 11        3199603.20             19798  3180600.68
# 12        4613443.34             28114  4588415.41

# %%
# More Efficient: Use .agg() ==> Good!

a7 =\
(
    a6
    .groupby(["Month"] # reset unit of analysis [by default, pd returns unit of analysis == unit of observation]
            )
    .agg({"Gross Revenue": "sum",
          "Quantity Ordered": "median",
          "Price Each": "mean"}
        )
)

a7
# Out:
#        Gross Revenue  Quantity Ordered  Price Each
# Month
# 1         1822256.73               1.0  186.607105
# 2         2202022.42               1.0  182.787868
# 3         2807100.38               1.0  184.201665
# 4         3390670.24               1.0  184.237158
# 5         3152606.75               1.0  189.250581
# 6         2577802.26               1.0  189.023580
# 7         2647775.76               1.0  184.183835
# 8         2244467.88               1.0  186.468140
# 9         2097560.13               1.0  179.415893
# 10        3736726.88               1.0  183.194696
# 11        3199603.20               1.0  180.993608
# 12        4613443.34               1.0  183.654155

# %%
# Combinations of Operations ==> BETTER!

op_A =\
    {"Gross Revenue": "mean",
     "Quantity Ordered": "sum"}

op_B =\
    {"Gross Revenue": "sum",
     "Quantity Ordered": "median"}

op_C =\
    {"Gross Revenue": "median",
     "Quantity Ordered": "mean"}

###

# %%
a6\
    .groupby(["Month"]
            )\
    .agg(op_C)
# Out:
#        Gross Revenue  Quantity Ordered
# Month
# 1              14.95          1.122979
# 2              14.95          1.123090
# 3              14.95          1.122220
# 4              14.95          1.124679
# 5              14.95          1.126826
# 6              14.95          1.125350
# 7              14.95          1.124467
# 8              14.95          1.124321
# 9              14.95          1.128044
# 10             14.95          1.119367
# 11             14.95          1.126615
# 12             14.95          1.125280

# %% [markdown]
# ### Question 8. Please create a vertical bar plot that summarizes the `monthly` `gross revenue`.

# %%
plt\
    .bar(a7.index,
         a7["Gross Revenue"]
        )

plt\
    .xticks(a7.index)
# Out:
# ([<matplotlib.axis.XTick at 0x3540e7370>,
#   <matplotlib.axis.XTick at 0x3540e7340>,
#   <matplotlib.axis.XTick at 0x3540e6b90>,
#   <matplotlib.axis.XTick at 0x35415c7c0>,
#   <matplotlib.axis.XTick at 0x35415d270>,
#   <matplotlib.axis.XTick at 0x35415dd20>,
#   <matplotlib.axis.XTick at 0x35415e7d0>,
#   <matplotlib.axis.XTick at 0x35415cdc0>,
#   <matplotlib.axis.XTick at 0x35415f1f0>,
#   <matplotlib.axis.XTick at 0x35415fca0>,
#   <matplotlib.axis.XTick at 0x354180790>,
#   <matplotlib.axis.XTick at 0x354181240>],
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12')])

# %%
months = range(1, 13)

top_month_INDEX =\
(
    a7
    ["Gross Revenue"]
    .idxmax()
)

colors =\
    ["blue" if i != top_month_INDEX 
     else "red" 
     for i
     in a7.index]

plt\
    .bar(months,
         a7["Gross Revenue"],
         color = colors)

plt.xticks(months)

plt.title("Gross Revenue by Month with Top Month with Red Color")
# Out:
# Text(0.5, 1.0, 'Gross Revenue by Month with Top Month with Red Color')

# %% [markdown]
# ### Question 9: What `City` sold the most product based on `Quantity Ordered` and `Gross Revenue`?

# %%
a6.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'interim_string', 'city_state',
#        'Gross Revenue'],
#       dtype='object')

# %%
op =\
    {"Gross Revenue": "sum",
     "Quantity Ordered": "sum"}

a9 =\
(
    a6
    .groupby(["city_state"] # reset unit of analysis at each city_state level
            )
    .agg(op)
)

a9
# Out:
#                   Gross Revenue  Quantity Ordered
# city_state
# Atlanta GA           2795498.58             16602
# Austin TX            1819581.75             11153
# Boston MA            3661642.01             22528
# Dallas TX            2767975.40             16730
# Los Angeles CA       5452570.80             33289
# New York City NY     4664317.43             27932
# Portland ME           449758.27              2750
# Portland OR          1870732.34             11303
# San Francisco CA     8262203.91             50239
# Seattle WA           2747755.48             16553

# %% [markdown]
# ### Question 10. Please visualize the above results with `horizontal` bar plot.

# %%
(
    a9
    .sort_values(by = "Gross Revenue")
)

# %%
plt\
    .barh(a9.sort_values(by = "Gross Revenue").index,
          a9.sort_values(by = "Gross Revenue")["Gross Revenue"]
        )
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Question 11: What time should we display ads to maximize likelihood of customer's buying product? Please create a new variable `Hour` from column `Order Date`

# %%
a6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186849
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int64
#  7   interim_string    185950 non-null  object
#  8   city_state        185950 non-null  object
#  9   Gross Revenue     185950 non-null  float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 19.6+ MB

# %%
a6[["Order Date"]]
# Out:
#             Order Date
# 0       01/22/19 21:25
# 1       01/28/19 14:15
# 2       01/17/19 13:33
# 3       01/05/19 20:33
# 4       01/25/19 11:59
# ...                ...
# 186845  12/11/19 20:58
# 186846  12/01/19 12:01
# 186847  12/09/19 06:43
# 186848  12/03/19 10:39
# 186849  12/21/19 21:45
#
# [185950 rows x 1 columns]

# %%
a6["hour"] =\
(
    pd
    .to_datetime(a6["Order Date"]
                )
    .dt
    .hour
)
# Out:
# /var/folders/92/v3m3bh610pz80xs31zwcwtcc0000gn/T/ipykernel_5662/2662400187.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   .to_datetime(a6["Order Date"]

# %%
a6[["hour", "Order Date"]]
# Out:
#         hour      Order Date
# 0         21  01/22/19 21:25
# 1         14  01/28/19 14:15
# 2         13  01/17/19 13:33
# 3         20  01/05/19 20:33
# 4         11  01/25/19 11:59
# ...      ...             ...
# 186845    20  12/11/19 20:58
# 186846    12  12/01/19 12:01
# 186847     6  12/09/19 06:43
# 186848    10  12/03/19 10:39
# 186849    21  12/21/19 21:45
#
# [185950 rows x 2 columns]

# %%
# a6["count_of_order"] = 1

# %%
type(
    a6
    .hour
    .value_counts()
)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Question 12. Please visualize the results of your analysis above.

# %%
hour_level_data =\
(
    a6
    .groupby(["hour"]
            )
    .size()
)

hour_level_data
# Out:
# hour
# 0      3910
# 1      2350
# 2      1243
# 3       831
# 4       854
# 5      1321
# 6      2482
# 7      4011
# 8      6256
# 9      8748
# 10    10944
# 11    12411
# 12    12587
# 13    12129
# 14    10984
# 15    10175
# 16    10384
# 17    10899
# 18    12280
# 19    12905
# 20    12228
# 21    10921
# 22     8822
# 23     6275
# dtype: int64

# %%
plt\
    .plot(np.array(hour_level_data.index),
          np.array(hour_level_data.values),
          "r-o"
         )

plt\
    .xticks(np.array(hour_level_data.index)
           )

plt\
    .grid()

# %% [markdown]
# ### <font color="green">"Thank you for putting your efforts into the exercise questions"</font>
